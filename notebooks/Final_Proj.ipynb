# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install matplotlib
# !pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
def get_flight_status(cancelled, dep_delay):
    flight_status = np.where(cancelled, 'Cancelled', np.where(dep_delay > 0, 'Delayed', 'On Time'))
    return flight_status

# %%
import pandas as pd
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

print(sklearn.__version__)

le = LabelEncoder()

df = pd.read_csv("Combined_Flights_2021.csv", 
                 usecols=['Airline', 'Origin', 'Dest', 'Cancelled', 'DepTime', 'DepDelay', \
                          'Month', 'DayOfWeek', 'OriginCityName', 'OriginStateName', 'DestCityName', 'DestStateName', 'Distance'], 
                 dtype={
                     
            'Airline': 'str',
            'Origin': 'str',
            'Dest': 'str',
            'Cancelled': 'bool', # Part of FlightStatus
            'DepTime': 'float64', 
            'DepDelay': 'float64', # Part of FlightStatus
            'Month': 'str',
            'DayOfWeek': 'int64',
            'OriginCityName' : 'str',
            'OriginStateName' : 'str',
            'DestCityName' : 'str',
            'DestStateName' : 'str',
            'Distance': 'float64'
})


df['FlightStatus'] = get_flight_status(df['Cancelled'], df['DepDelay'])

le.fit(df['Airline'])
df['Airline'] = le.fit_transform(df['Airline'])

le.fit(df['Origin'])
df['Origin'] = le.fit_transform(df['Origin'])

le.fit(df['Dest'])
df['Dest'] = le.fit_transform(df['Dest'])

le.fit(df['Month'])
df['Month'] = le.fit_transform(df['Month'])

le.fit(df['OriginCityName'])
df['OriginCityName'] = le.fit_transform(df['OriginCityName'])

le.fit(df['OriginStateName'])
df['OriginStateName'] = le.fit_transform(df['OriginStateName'])

le.fit(df['DestCityName'])
df['DestCityName'] = le.fit_transform(df['DestCityName'])

le.fit(df['DestStateName'])
df['DestStateName'] = le.fit_transform(df['DestStateName'])

le.fit(df['FlightStatus'])
df['FlightStatus'] = le.fit_transform(df['FlightStatus'])

df = df.reset_index()

df = df.drop(columns='DepDelay')
df = df.drop(columns='Cancelled')

print(sklearn.__version__)

df
# Out:
# 1.4.1.post1
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# 1.4.1.post1
#            index  Airline  Origin  Dest  DepTime  Distance  Month  DayOfWeek  \
# 0              0       18     328   275    714.0     262.0      5          3
# 1              1       18     275   328    917.0     262.0      5          3
# 2              2       18     232   260   1321.0     843.0      5          3
# 3              3       18      99   359   1636.0     868.0      5          3
# 4              4       18     275    34   1838.0     425.0      5          3
# ...          ...      ...     ...   ...      ...       ...    ...        ...
# 6311866  6311866       19      46   225   1301.0     395.0      8          2
# 6311867  6311867       19      46   225    727.0     395.0      8          2
# 6311868  6311868       19      46   233    757.0     806.0      8          2
# ...

# %%
df.fillna(0)
# Out:
#            index  Airline  Origin  Dest  DepTime  Distance  Month  DayOfWeek  \
# 0              0       18     328   275    714.0     262.0      5          3
# 1              1       18     275   328    917.0     262.0      5          3
# 2              2       18     232   260   1321.0     843.0      5          3
# 3              3       18      99   359   1636.0     868.0      5          3
# 4              4       18     275    34   1838.0     425.0      5          3
# ...          ...      ...     ...   ...      ...       ...    ...        ...
# 6311866  6311866       19      46   225   1301.0     395.0      8          2
# 6311867  6311867       19      46   225    727.0     395.0      8          2
# 6311868  6311868       19      46   233    757.0     806.0      8          2
# 6311869  6311869       19      46   233   1252.0     806.0      8          2
# 6311870  6311870       19      46   234   1948.0     475.0      8          2
#
# ...

# %%
# %%time
# Decision Tree Clasification
from sklearn import tree
from imblearn.over_sampling import RandomOverSampler
# Train the model
dct = tree.DecisionTreeClassifier()
x = df.drop(columns='FlightStatus')
y = df['FlightStatus']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)
dct = dct.fit(X_train, y_train)
X_train.shape
# Out:
# CPU times: user 1min 17s, sys: 271 ms, total: 1min 17s
# Wall time: 1min 17s
# (4418309, 12)

# %%
# %%time
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
predicts = dct.predict(X_test)
print(f"Accuracy Score: {accuracy_score(y_test, predicts)}")
print(f"F1 Score: {f1_score(y_test, predicts, average='weighted')}")
print(f"Balanced Accuracy Score: {balanced_accuracy_score(y_test, predicts)}")
X_test.shape
# Out:
# Accuracy Score: 0.828179906440877
# F1 Score: 0.8267931288714732
# Balanced Accuracy Score: 0.8558657937653367
# CPU times: user 2.46 s, sys: 32 ms, total: 2.49 s
# Wall time: 2.48 s
# (1893562, 12)

# %%
# %%time
# Naive Bayes Classification
from sklearn.naive_bayes import GaussianNB
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp = imp.fit(df)
x =  pd.DataFrame(imp.transform(df), columns=df.columns, index=df.index).drop(columns='FlightStatus')
y =  pd.DataFrame(imp.transform(df), columns=df.columns, index=df.index)['FlightStatus']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42, stratify=y)
gs = GaussianNB()
gs = gs.fit(X_train, y_train)
X_train.shape
# Out:
# CPU times: user 8.29 s, sys: 764 ms, total: 9.05 s
# Wall time: 9.05 s
# (4418309, 12)

# %%
# %%time
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
predicts = gs.predict(X_test)
print(f"Accuracy Score: {accuracy_score(y_test, predicts)}")
print(f"F1 Score: {f1_score(y_test, predicts, average='weighted')}")
print(f"Balanced Accuracy Score: {balanced_accuracy_score(y_test, predicts)}")
X_test.shape
# Out:
# Accuracy Score: 0.6619777963436106
# F1 Score: 0.5821260158573163
# Balanced Accuracy Score: 0.3567743965806231
# CPU times: user 2.15 s, sys: 91.9 ms, total: 2.25 s
# Wall time: 2.24 s
# (1893562, 12)
